# %%
import glob, cv2, os, re
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Creamos el archivo para negativas que se encuentran en train/negatives

# %% [markdown]
# #### Primero renombramos las imagenes negativas

# %%
imgs = glob.glob('train/negatives/*jpg')
[os.rename(im, f'{im[0:16]}neg{"0"*(4-len(str(i)))}{str(i)}.jpg') for i,im in enumerate(imgs)];
#[os.rename(e,e[:-4]+str(i)+".jpg") for i, im in enumerate(img) for e in im]

# %%
routes = glob.glob('train/negatives/*.tiff')
f= open("bg.txt","w+")
for i,route in enumerate(routes):
    f.write(f"{route}\n")
f.close()

# %% [markdown]
# ## Creamos nuestras imagenes positivas a partir de las que tenemos en la carpeta train/positives

# %%
### igualamos tamaño para las positivas

# %%
routes = glob.glob('train/positives/*.png')
imagenes = [cv2.imread(route) for route in routes]
imagenes_res = [cv2.resize(imagen[:,:,0], (34,34), interpolation = cv2.INTER_AREA) for imagen in imagenes]
[matplotlib.image.imsave(f'train/positives/pos{i}.png', im) for i, im in enumerate(imagenes_res)]
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# #### Creamos el archivo info de las imagenes con las que crearemos las imagenes positivas

# %%
routes = glob.glob('train/positives/*.png')
f= open("sample.txt","w+")
#[f.write(f"{route} 1 0 0 34 34\n") for route in routes]
f.write(f"train/positives/pos0.png 1 0 0 34 34\n")
f.close()

# %%
# !pwd
# Out:
# /home/jmpchamizo/Repositorios/final_project/train/negatives

# %%
cd ..
# Out:
# /home/jmpchamizo/Repositorios/final_project/train

# %%
# !opencv_createsamples -img train/positives/pos0.png -bg bg.txt -info pos00.txt -num 3700 -maxxangle 0.5 -maxyangle 0.5 maxzangle 0.2 -bgcolor 0 -mode ALL -w 34 -h 34
# Out:
# Info file name: pos00.txt
# Img file name: train/positives/pos0.png
# Vec file name: (NULL)
# BG  file name: bg.txt
# Num: 3700
# BG color: 0
# BG threshold: 80
# Invert: FALSE
# Max intensity deviation: 40
# Max x angle: 0.5
# Max y angle: 0.5
# Max z angle: 0.5
# Show samples: FALSE
# Width: 34
# Height: 34
# Max Scale: -1
# RNG Seed: 12345
# Create test samples from single image applying distortions...
# Open background image: train/negatives/251.tiff
# Open background image: train/negatives/811.tiff
# Open background image: train/negatives/1186.tiff
# Open background image: train/negatives/4480.tiff
# Open background image: train/negatives/2471.tiff
# Open background image: train/negatives/2520.tiff
# Open background image: train/negatives/5194.tiff
# Open background image: train/negatives/187false.tiff
# Open background image: train/negatives/3524.tiff
# Open background image: train/negatives/2929.tiff
# Open background image: train/negatives/1077.tiff
# Open background image: train/negatives/225false.tiff
# Open background image: train/negatives/1156.tiff
# Open background image: train/negatives/310false.tiff
# Open background image: train/negatives/1696.tiff
# Open background image: train/negatives/4772.tiff
# Open background image: train/negatives/989.tiff
# Open background image: train/negatives/3570.tiff
# Open background image: train/negatives/681false.tiff
# Open background image: train/negatives/611false.tiff
# Open background image: train/negatives/4827.tiff
# Open background image: train/negatives/2643.tiff
# Open background image: train/negatives/4242.tiff
# Open background image: train/negatives/2906.tiff
# Open background image: train/negatives/3623.tiff
# Open background image: train/negatives/1621.tiff
# Open background image: train/negatives/813.tiff
# Open background image: train/negatives/4143.tiff
# Open background image: train/negatives/5079.tiff
# Open background image: train/negatives/327false.tiff
# Open background image: train/negatives/4995.tiff
# Open background image: train/negatives/4013.tiff
# Open background image: train/negatives/1927.tiff
# Open background image: train/negatives/1576.tiff
# Open background image: train/negatives/3712.tiff
# Open background image: train/negatives/2028.tiff
# Open background image: train/negatives/174.tiff
# Open background image: train/negatives/839false.tiff
# Open background image: train/negatives/929.tiff
# Open background image: train/negatives/424false.tiff
# Open background image: train/negatives/802.tiff
# Open background image: train/negatives/2289.tiff
# Open background image: train/negatives/4948.tiff
# Open background image: train/negatives/4122.tiff
# Open background image: train/negatives/644.tiff
# Open background image: train/negatives/1988.tiff
# Open background image: train/negatives/690false.tiff
# Open background image: train/negatives/2482.tiff
# Open background image: train/negatives/216false.tiff
# Open background image: train/negatives/761false.tiff
# Open background image: train/negatives/3013.tiff
# Open background image: train/negatives/1838.tiff
# Open background image: train/negatives/1688.tiff
# Open background image: train/negatives/128.tiff
# Open background image: train/negatives/21false.tiff
# Open background image: train/negatives/4087.tiff
# Open background image: train/negatives/4090.tiff
# Open background image: train/negatives/730.tiff
# Open background image: train/negatives/4479.tiff
# Open background image: train/negatives/4392.tiff
# Open background image: train/negatives/4801.tiff
# Open background image: train/negatives/1808.tiff
# Open background image: train/negatives/2201.tiff
# Open background image: train/negatives/124false.tiff
# Open background image: train/negatives/765false.tiff
# Open background image: train/negatives/1233.tiff
# Open background image: train/negatives/1934.tiff
# Open background image: train/negatives/4688.tiff
# Open background image: train/negatives/1470.tiff
# Open background image: train/negatives/116false.tiff
# Open background image: train/negatives/1545.tiff
# Open background image: train/negatives/138.tiff
# Open background image: train/negatives/3513.tiff
# Open background image: train/negatives/1685.tiff
# Open background image: train/negatives/3991.tiff
# Open background image: train/negatives/2912.tiff
# Open background image: train/negatives/2396.tiff
# Open background image: train/negatives/3413.tiff
# Open background image: train/negatives/2071.tiff
# Open background image: train/negatives/46false.tiff
# Open background image: train/negatives/2457.tiff
# Open background image: train/negatives/2688.tiff
# Open background image: train/negatives/299false.tiff
# Open background image: train/negatives/5015.tiff
# Open background image: train/negatives/384.tiff
# Open background image: train/negatives/4075.tiff
# Open background image: train/negatives/491false.tiff
# Open background image: train/negatives/3823.tiff
# Open background image: train/negatives/3757.tiff
# Open background image: train/negatives/177.tiff
# Open background image: train/negatives/384.tiff
# Open background image: train/negatives/1525.tiff
# Open background image: train/negatives/537.tiff
# Open background image: train/negatives/529.tiff
# Open background image: train/negatives/2876.tiff
# Open background image: train/negatives/141false.tiff
# Open background image: train/negatives/790.tiff
# Open background image: train/negatives/344.tiff
# Open background image: train/negatives/2698.tiff
# Open background image: train/negatives/747false.tiff
# Open background image: train/negatives/2503.tiff
# Open background image: train/negatives/848.tiff
# Open background image: train/negatives/1103.tiff
# Open background image: train/negatives/1766.tiff
# Open background image: train/negatives/2240.tiff
# Open background image: train/negatives/4293.tiff
# Open background image: train/negatives/637false.tiff
# Open background image: train/negatives/440.tiff
# Open background image: train/negatives/175.tiff
# Open background image: train/negatives/4107.tiff
# Open background image: train/negatives/3910.tiff
# Open background image: train/negatives/4057.tiff
# Open background image: train/negatives/675false.tiff
# Open background image: train/negatives/2712.tiff
# Open background image: train/negatives/1216.tiff
# Open background image: train/negatives/116.tiff
# Open background image: train/negatives/254.tiff
# Open background image: train/negatives/2063.tiff
# Open background image: train/negatives/4875.tiff
# Open background image: train/negatives/3936.tiff
# Open background image: train/negatives/1863.tiff
# Open background image: train/negatives/347false.tiff
# Open background image: train/negatives/2731.tiff
# Open background image: train/negatives/3057.tiff
# Open background image: train/negatives/3644.tiff
# Open background image: train/negatives/431.tiff
# Open background image: train/negatives/967.tiff
# Open background image: train/negatives/1821.tiff
# Open background image: train/negatives/2341.tiff
# Open background image: train/negatives/68false.tiff
# Open background image: train/negatives/2695.tiff
# Open background image: train/negatives/1591.tiff
# Open background image: train/negatives/730.tiff
# Open background image: train/negatives/185false.tiff
# Open background image: train/negatives/569.tiff
# Open background image: train/negatives/595.tiff
# Open background image: train/negatives/883false.tiff
# Open background image: train/negatives/240.tiff
# Open background image: train/negatives/481.tiff
# Open background image: train/negatives/1047.tiff
# Open background image: train/negatives/2364.tiff
# Open background image: train/negatives/142false.tiff
# Open background image: train/negatives/3449.tiff
# Open background image: train/negatives/1826.tiff
# Open background image: train/negatives/3328.tiff
# Open background image: train/negatives/4086.tiff
# Open background image: train/negatives/1069.tiff
# Open background image: train/negatives/3453.tiff
# Open background image: train/negatives/868false.tiff
# Open background image: train/negatives/630.tiff
# Open background image: train/negatives/4945.tiff
# Open background image: train/negatives/876false.tiff
# Open background image: train/negatives/747false.tiff
# Open background image: train/negatives/2337.tiff
# Open background image: train/negatives/3040.tiff
# Open background image: train/negatives/4372.tiff
# Open background image: train/negatives/1104.tiff
# Open background image: train/negatives/5218.tiff
# Open background image: train/negatives/4870.tiff
# Open background image: train/negatives/617false.tiff
# Open background image: train/negatives/722.tiff
# Open background image: train/negatives/1921.tiff
# Open background image: train/negatives/114false.tiff
# Open background image: train/negatives/2016.tiff
# Open background image: train/negatives/456.tiff
# Open background image: train/negatives/1816.tiff
# Open background image: train/negatives/951.tiff
# Open background image: train/negatives/2295.tiff
# Open background image: train/negatives/1763.tiff
# Open background image: train/negatives/4621.tiff
# Open background image: train/negatives/356.tiff
# Open background image: train/negatives/3431.tiff
# Open background image: train/negatives/1103.tiff
# Open background image: train/negatives/5179.tiff
# Open background image: train/negatives/3313.tiff
# Open background image: train/negatives/929.tiff
# Open background image: train/negatives/2278.tiff
# Open background image: train/negatives/418false.tiff
# Open background image: train/negatives/508false.tiff
# Open background image: train/negatives/2851.tiff
# Open background image: train/negatives/4316.tiff
# Open background image: train/negatives/3789.tiff
# Open background image: train/negatives/978false.tiff
# Open background image: train/negatives/2609.tiff
# Open background image: train/negatives/2074.tiff
# Open background image: train/negatives/4301.tiff
# Open background image: train/negatives/5091.tiff
# Open background image: train/negatives/4941.tiff
# Open background image: train/negatives/549false.tiff
# Open background image: train/negatives/3464.tiff
# Open background image: train/negatives/4743.tiff
# Open background image: train/negatives/4415.tiff
# Open background image: train/negatives/66.tiff
# Open background image: train/negatives/862false.tiff
# Open background image: train/negatives/1699.tiff
# Open background image: train/negatives/3495.tiff
# Open background image: train/negatives/1086.tiff
# Open background image: train/negatives/4844.tiff
# Open background image: train/negatives/1935.tiff
# Open background image: train/negatives/893.tiff
# Open background image: train/negatives/2174.tiff
# Open background image: train/negatives/121false.tiff
# Open background image: train/negatives/85false.tiff
# Open background image: train/negatives/567.tiff
# Open background image: train/negatives/40.tiff
# Open background image: train/negatives/2365.tiff
# Open background image: train/negatives/1176.tiff
# Open background image: train/negatives/2336.tiff
# Open background image: train/negatives/97.tiff
# Open background image: train/negatives/482.tiff
# Open background image: train/negatives/871false.tiff
# Open background image: train/negatives/251false.tiff
# Open background image: train/negatives/4402.tiff
# Open background image: train/negatives/6.tiff
# Open background image: train/negatives/94false.tiff
# Open background image: train/negatives/420.tiff
# Open background image: train/negatives/456false.tiff
# Open background image: train/negatives/5013.tiff
# Open background image: train/negatives/538false.tiff
# Open background image: train/negatives/4467.tiff
# Open background image: train/negatives/4638.tiff
# Open background image: train/negatives/4605.tiff
# Open background image: train/negatives/5217.tiff
# Open background image: train/negatives/1542.tiff
# Open background image: train/negatives/198.tiff
# Open background image: train/negatives/421.tiff
# Open background image: train/negatives/1702.tiff
# Open background image: train/negatives/32.tiff
# Open background image: train/negatives/3861.tiff
# Open background image: train/negatives/1514.tiff
# Open background image: train/negatives/4746.tiff
# Open background image: train/negatives/2068.tiff
# Open background image: train/negatives/1825.tiff
# Open background image: train/negatives/2328.tiff
# Open background image: train/negatives/83.tiff
# Open background image: train/negatives/68.tiff
# Open background image: train/negatives/3727.tiff
# Open background image: train/negatives/1072.tiff
# Open background image: train/negatives/4976.tiff
# Open background image: train/negatives/2051.tiff
# Open background image: train/negatives/2156.tiff
# Open background image: train/negatives/3881.tiff
# Open background image: train/negatives/38.tiff
# Open background image: train/negatives/3449.tiff
# Open background image: train/negatives/331.tiff
# Open background image: train/negatives/4501.tiff
# Open background image: train/negatives/1605.tiff
# Open background image: train/negatives/2503.tiff
# Open background image: train/negatives/672.tiff
# Open background image: train/negatives/5177.tiff
# Open background image: train/negatives/1569.tiff
# Open background image: train/negatives/692false.tiff
# Open background image: train/negatives/4707.tiff
# Open background image: train/negatives/557false.tiff
# Open background image: train/negatives/629.tiff
# Open background image: train/negatives/2353.tiff
# Open background image: train/negatives/702false.tiff
# Open background image: train/negatives/666.tiff
# Open background image: train/negatives/694.tiff
# Open background image: train/negatives/32.tiff
# Open background image: train/negatives/401.tiff
# Open background image: train/negatives/441false.tiff
# Open background image: train/negatives/4704.tiff
# Open background image: train/negatives/4276.tiff
# Open background image: train/negatives/4122.tiff
# Open background image: train/negatives/244.tiff
# Open background image: train/negatives/299.tiff
# Open background image: train/negatives/3412.tiff
# Open background image: train/negatives/3054.tiff
# Open background image: train/negatives/812false.tiff
# Open background image: train/negatives/4389.tiff
# Open background image: train/negatives/2856.tiff
# Open background image: train/negatives/652.tiff
# Open background image: train/negatives/4222.tiff
# Open background image: train/negatives/2695.tiff
# Open background image: train/negatives/4978.tiff
# Open background image: train/negatives/4494.tiff
# Open background image: train/negatives/2332.tiff
# Open background image: train/negatives/1966.tiff
# Open background image: train/negatives/5075.tiff
# Open background image: train/negatives/4638.tiff
# Open background image: train/negatives/1810.tiff
# Open background image: train/negatives/1816.tiff
# Open background image: train/negatives/3783.tiff
# Open background image: train/negatives/874.tiff
# Open background image: train/negatives/1480.tiff
# Open background image: train/negatives/4299.tiff
# Open background image: train/negatives/2740.tiff
# Open background image: train/negatives/340.tiff
# Open background image: train/negatives/3571.tiff
# Open background image: train/negatives/1048.tiff
# Open background image: train/negatives/5195.tiff
# Open background image: train/negatives/2626.tiff
# Open background image: train/negatives/720.tiff
# Open background image: train/negatives/3412.tiff
# Open background image: train/negatives/812false.tiff
# Open background image: train/negatives/5169.tiff
# Open background image: train/negatives/2709.tiff
# Open background image: train/negatives/3518.tiff
# Open background image: train/negatives/3529.tiff
# Open background image: train/negatives/633.tiff
# Open background image: train/negatives/711false.tiff
# Open background image: train/negatives/1599.tiff
# Open background image: train/negatives/3388.tiff
# Open background image: train/negatives/885false.tiff
# Open background image: train/negatives/536.tiff
# Open background image: train/negatives/4575.tiff
# Open background image: train/negatives/957false.tiff
# Open background image: train/negatives/2073.tiff
# Open background image: train/negatives/997false.tiff
# Open background image: train/negatives/1187.tiff
# Open background image: train/negatives/691false.tiff
# Open background image: train/negatives/32false.tiff
# Open background image: train/negatives/946.tiff
# Open background image: train/negatives/991false.tiff
# Open background image: train/negatives/3605.tiff
# Open background image: train/negatives/2980.tiff
# Open background image: train/negatives/1746.tiff
# Open background image: train/negatives/4298.tiff
# Open background image: train/negatives/3055.tiff
# Open background image: train/negatives/3535.tiff
# Open background image: train/negatives/890.tiff
# Open background image: train/negatives/2590.tiff
# Open background image: train/negatives/12false.tiff
# Open background image: train/negatives/3497.tiff
# Open background image: train/negatives/2853.tiff
# Open background image: train/negatives/903false.tiff
# Open background image: train/negatives/81.tiff
# Open background image: train/negatives/539false.tiff
# Open background image: train/negatives/3991.tiff
# Open background image: train/negatives/1734.tiff
# Open background image: train/negatives/2090.tiff
# Open background image: train/negatives/77false.tiff
# Open background image: train/negatives/369.tiff
# Open background image: train/negatives/4804.tiff
# Open background image: train/negatives/2581.tiff
# Open background image: train/negatives/3689.tiff
# Open background image: train/negatives/1576.tiff
# Open background image: train/negatives/3485.tiff
# Open background image: train/negatives/3767.tiff
# Open background image: train/negatives/4976.tiff
# Open background image: train/negatives/2605.tiff
# Open background image: train/negatives/564false.tiff
# Open background image: train/negatives/794.tiff
# Open background image: train/negatives/703.tiff
# Open background image: train/negatives/3926.tiff
# Open background image: train/negatives/518false.tiff
# Open background image: train/negatives/879false.tiff
# Open background image: train/negatives/3659.tiff
# Open background image: train/negatives/5072.tiff
# Open background image: train/negatives/867.tiff
# Open background image: train/negatives/765false.tiff
# Open background image: train/negatives/3559.tiff
# Open background image: train/negatives/484.tiff
# Open background image: train/negatives/4077.tiff
# Open background image: train/negatives/3359.tiff
# Open background image: train/negatives/8false.tiff
# Open background image: train/negatives/5027.tiff
# Open background image: train/negatives/57.tiff
# Open background image: train/negatives/273false.tiff
# Open background image: train/negatives/2237.tiff
# Open background image: train/negatives/1194.tiff
# Open background image: train/negatives/621false.tiff
# Open background image: train/negatives/3431.tiff
# Open background image: train/negatives/2645.tiff
# Open background image: train/negatives/4589.tiff
# Open background image: train/negatives/460.tiff
# Open background image: train/negatives/4337.tiff
# Open background image: train/negatives/3806.tiff
# Open background image: train/negatives/2827.tiff
# Open background image: train/negatives/1503.tiff
# Open background image: train/negatives/2382.tiff
# Open background image: train/negatives/563.tiff
# Open background image: train/negatives/4198.tiff
# Open background image: train/negatives/3482.tiff
# Open background image: train/negatives/2142.tiff
# Open background image: train/negatives/551.tiff
# Open background image: train/negatives/1853.tiff
# Open background image: train/negatives/76false.tiff
# Open background image: train/negatives/923.tiff
# Open background image: train/negatives/1224.tiff
# Open background image: train/negatives/60false.tiff
# Open background image: train/negatives/19.tiff
# Open background image: train/negatives/1578.tiff
# Open background image: train/negatives/3847.tiff
# Open background image: train/negatives/1485.tiff
# Open background image: train/negatives/2338.tiff
# Open background image: train/negatives/388false.tiff
# Open background image: train/negatives/1false.tiff
# Open background image: train/negatives/515.tiff
# Open background image: train/negatives/977.tiff
# Open background image: train/negatives/1907.tiff
# Open background image: train/negatives/2740.tiff
# Open background image: train/negatives/732false.tiff
# Open background image: train/negatives/578.tiff
# Open background image: train/negatives/785.tiff
# Open background image: train/negatives/3554.tiff
# Open background image: train/negatives/70.tiff
# Open background image: train/negatives/1977.tiff
# Open background image: train/negatives/180.tiff
# Open background image: train/negatives/997false.tiff
# Open background image: train/negatives/348.tiff
# Open background image: train/negatives/1514.tiff
# Open background image: train/negatives/457.tiff
# Open background image: train/negatives/1823.tiff
# Open background image: train/negatives/1543.tiff
# Open background image: train/negatives/1679.tiff
# Open background image: train/negatives/4574.tiff
# Open background image: train/negatives/2042.tiff
# Open background image: train/negatives/849false.tiff
# Open background image: train/negatives/4342.tiff
# Open background image: train/negatives/2105.tiff
# Open background image: train/negatives/358.tiff
# Open background image: train/negatives/1693.tiff
# Open background image: train/negatives/2065.tiff
# Open background image: train/negatives/2847.tiff
# Open background image: train/negatives/4022.tiff
# Open background image: train/negatives/4124.tiff
# Open background image: train/negatives/676.tiff
# Open background image: train/negatives/4558.tiff
# Open background image: train/negatives/399false.tiff
# Open background image: train/negatives/5202.tiff
# Open background image: train/negatives/2534.tiff
# Open background image: train/negatives/2967.tiff
# Open background image: train/negatives/2154.tiff
# Open background image: train/negatives/1900.tiff
# Open background image: train/negatives/188false.tiff
# Open background image: train/negatives/1105.tiff
# Open background image: train/negatives/1991.tiff
# Open background image: train/negatives/5137.tiff
# Open background image: train/negatives/3692.tiff
# Open background image: train/negatives/2289.tiff
# Open background image: train/negatives/207.tiff
# Open background image: train/negatives/229false.tiff
# Open background image: train/negatives/1498.tiff
# Open background image: train/negatives/2801.tiff
# Open background image: train/negatives/1471.tiff
# Open background image: train/negatives/5071.tiff
# Open background image: train/negatives/215false.tiff
# Open background image: train/negatives/4812.tiff
# Open background image: train/negatives/3955.tiff
# Open background image: train/negatives/679.tiff
# Open background image: train/negatives/738false.tiff
# Open background image: train/negatives/927false.tiff
# Open background image: train/negatives/965false.tiff
# Open background image: train/negatives/4096.tiff
# Open background image: train/negatives/747.tiff
# Open background image: train/negatives/855.tiff
# Open background image: train/negatives/2893.tiff
# Open background image: train/negatives/2520.tiff
# Open background image: train/negatives/364.tiff
# Open background image: train/negatives/2884.tiff
# Open background image: train/negatives/1059.tiff
# Open background image: train/negatives/418.tiff
# Open background image: train/negatives/5057.tiff
# Open background image: train/negatives/1734.tiff
# Open background image: train/negatives/373false.tiff
# Open background image: train/negatives/2930.tiff
# Open background image: train/negatives/1132.tiff
# Open background image: train/negatives/1483.tiff
# Open background image: train/negatives/438.tiff
# Open background image: train/negatives/713.tiff
# Open background image: train/negatives/226false.tiff
# Open background image: train/negatives/3876.tiff
# Open background image: train/negatives/4590.tiff
# Open background image: train/negatives/2512.tiff
# Open background image: train/negatives/3398.tiff
# Open background image: train/negatives/614false.tiff
# Open background image: train/negatives/543false.tiff
# Open background image: train/negatives/110false.tiff
# Open background image: train/negatives/2045.tiff
# Open background image: train/negatives/1751.tiff
# Open background image: train/negatives/2940.tiff
# Open background image: train/negatives/2564.tiff
# Open background image: train/negatives/2290.tiff
# Open background image: train/negatives/919false.tiff
# Open background image: train/negatives/3537.tiff
# Open background image: train/negatives/111.tiff
# Open background image: train/negatives/260.tiff
# Open background image: train/negatives/704false.tiff
# Open background image: train/negatives/401.tiff
# Open background image: train/negatives/583false.tiff
# Open background image: train/negatives/4464.tiff
# Open background image: train/negatives/2134.tiff
# Open background image: train/negatives/631false.tiff
# Open background image: train/negatives/2766.tiff
# Open background image: train/negatives/2567.tiff
# Open background image: train/negatives/1709.tiff
# Open background image: train/negatives/79.tiff
# Open background image: train/negatives/705false.tiff
# Open background image: train/negatives/436false.tiff
# Open background image: train/negatives/1900.tiff
# Open background image: train/negatives/4643.tiff
# Open background image: train/negatives/261.tiff
# Open background image: train/negatives/2142.tiff
# Open background image: train/negatives/1537.tiff
# Open background image: train/negatives/444.tiff
# Open background image: train/negatives/1163.tiff
# Open background image: train/negatives/2328.tiff
# Open background image: train/negatives/1021.tiff
# Open background image: train/negatives/2148.tiff
# Open background image: train/negatives/28.tiff
# Open background image: train/negatives/4293.tiff
# Open background image: train/negatives/1125.tiff
# Open background image: train/negatives/426false.tiff
# Open background image: train/negatives/2026.tiff
# Open background image: train/negatives/4343.tiff
# Open background image: train/negatives/2062.tiff
# Open background image: train/negatives/1650.tiff
# Open background image: train/negatives/4139.tiff
# Open background image: train/negatives/2690.tiff
# Open background image: train/negatives/845false.tiff
# Open background image: train/negatives/412.tiff
# Open background image: train/negatives/189.tiff
# Open background image: train/negatives/95false.tiff
# Open background image: train/negatives/219.tiff
# Open background image: train/negatives/2524.tiff
# Open background image: train/negatives/298.tiff
# Open background image: train/negatives/2992.tiff
# Open background image: train/negatives/2906.tiff
# Open background image: train/negatives/4157.tiff
# Open background image: train/negatives/749false.tiff
# Open background image: train/negatives/1029.tiff
# Open background image: train/negatives/3699.tiff
# Open background image: train/negatives/112false.tiff
# Open background image: train/negatives/1741.tiff
# Open background image: train/negatives/2655.tiff
# Open background image: train/negatives/1666.tiff
# Open background image: train/negatives/866false.tiff
# Open background image: train/negatives/1.tiff
# Open background image: train/negatives/834false.tiff
# Open background image: train/negatives/425false.tiff
# Open background image: train/negatives/763.tiff
# Open background image: train/negatives/4676.tiff
# Open background image: train/negatives/3797.tiff
# Open background image: train/negatives/4005.tiff
# Open background image: train/negatives/4089.tiff
# Open background image: train/negatives/4739.tiff
# Open background image: train/negatives/42false.tiff
# Open background image: train/negatives/813false.tiff
# Open background image: train/negatives/1913.tiff
# Open background image: train/negatives/995.tiff
# Open background image: train/negatives/5091.tiff
# Open background image: train/negatives/190false.tiff
# Open background image: train/negatives/1787.tiff
# Open background image: train/negatives/1097.tiff
# Open background image: train/negatives/1705.tiff
# Open background image: train/negatives/4885.tiff
# Open background image: train/negatives/1536.tiff
# Open background image: train/negatives/4400.tiff
# Open background image: train/negatives/715false.tiff
# Open background image: train/negatives/706.tiff
# Open background image: train/negatives/2844.tiff
# Open background image: train/negatives/1118.tiff
# Open background image: train/negatives/388.tiff
# Open background image: train/negatives/1490.tiff
# Open background image: train/negatives/91.tiff
# Open background image: train/negatives/1650.tiff
# Open background image: train/negatives/609.tiff
# Open background image: train/negatives/1613.tiff
# Open background image: train/negatives/2363.tiff
# Open background image: train/negatives/2184.tiff
# Open background image: train/negatives/2886.tiff
# Open background image: train/negatives/2176.tiff
# Open background image: train/negatives/3940.tiff
# Open background image: train/negatives/6false.tiff
# Open background image: train/negatives/1988.tiff
# Open background image: train/negatives/912false.tiff
# Open background image: train/negatives/4882.tiff
# Open background image: train/negatives/5100.tiff
# Open background image: train/negatives/4429.tiff
# Open background image: train/negatives/517.tiff
# Open background image: train/negatives/1665.tiff
# Open background image: train/negatives/4945.tiff
# Open background image: train/negatives/4470.tiff
# Open background image: train/negatives/222false.tiff
# Open background image: train/negatives/2301.tiff
# Open background image: train/negatives/826false.tiff
# Open background image: train/negatives/2771.tiff
# Open background image: train/negatives/1023.tiff
# Open background image: train/negatives/3888.tiff
# Open background image: train/negatives/901false.tiff
# Open background image: train/negatives/1528.tiff
# Open background image: train/negatives/68.tiff
# Open background image: train/negatives/4955.tiff
# Open background image: train/negatives/1927.tiff
# Open background image: train/negatives/4447.tiff
# Open background image: train/negatives/1564.tiff
# Open background image: train/negatives/2167.tiff
# Open background image: train/negatives/3484.tiff
# Open background image: train/negatives/5060.tiff
# Open background image: train/negatives/1536.tiff
# Open background image: train/negatives/404false.tiff
# Open background image: train/negatives/2969.tiff
# Open background image: train/negatives/1899.tiff
# Open background image: train/negatives/352.tiff
# Open background image: train/negatives/2233.tiff
# Open background image: train/negatives/4452.tiff
# Open background image: train/negatives/1988.tiff
# Open background image: train/negatives/1550.tiff
# Open background image: train/negatives/4801.tiff
# Open background image: train/negatives/2757.tiff
# Open background image: train/negatives/434.tiff
# Open background image: train/negatives/3952.tiff
# Open background image: train/negatives/115false.tiff
# Open background image: train/negatives/544.tiff
# Open background image: train/negatives/2145.tiff
# Open background image: train/negatives/3752.tiff
# Open background image: train/negatives/645false.tiff
# Open background image: train/negatives/4763.tiff
# Open background image: train/negatives/365.tiff
# Open background image: train/negatives/278false.tiff
# Open background image: train/negatives/178.tiff
# Open background image: train/negatives/761.tiff
# Open background image: train/negatives/848.tiff
# Open background image: train/negatives/547false.tiff
# Open background image: train/negatives/2299.tiff
# Open background image: train/negatives/3323.tiff
# Open background image: train/negatives/1669.tiff
# Open background image: train/negatives/2007.tiff
# Open background image: train/negatives/1218.tiff
# Open background image: train/negatives/960false.tiff
# Open background image: train/negatives/888false.tiff
# Open background image: train/negatives/2257.tiff
# Open background image: train/negatives/902.tiff
# Open background image: train/negatives/503false.tiff
# Open background image: train/negatives/1844.tiff
# Open background image: train/negatives/4075.tiff
# Open background image: train/negatives/84.tiff
# Open background image: train/negatives/4248.tiff
# Open background image: train/negatives/410.tiff
# Open background image: train/negatives/1983.tiff
# Open background image: train/negatives/443.tiff
# Open background image: train/negatives/500.tiff
# Open background image: train/negatives/2223.tiff
# Open background image: train/negatives/39.tiff
# Open background image: train/negatives/124false.tiff
# Open background image: train/negatives/643.tiff
# Open background image: train/negatives/1955.tiff
# Open background image: train/negatives/3482.tiff
# Open background image: train/negatives/98false.tiff
# Open background image: train/negatives/2938.tiff
# Open background image: train/negatives/4855.tiff
# Open background image: train/negatives/2248.tiff
# Open background image: train/negatives/289false.tiff
# Open background image: train/negatives/1810.tiff
# Open background image: train/negatives/653.tiff
# Open background image: train/negatives/3981.tiff
# Open background image: train/negatives/5137.tiff
# Open background image: train/negatives/4404.tiff
# Open background image: train/negatives/3660.tiff
# Open background image: train/negatives/1190.tiff
# Open background image: train/negatives/2880.tiff
# Open background image: train/negatives/609.tiff
# Open background image: train/negatives/5143.tiff
# Open background image: train/negatives/3006.tiff
# Open background image: train/negatives/816false.tiff
# Open background image: train/negatives/1491.tiff
# Open background image: train/negatives/742false.tiff
# Open background image: train/negatives/1739.tiff
# Open background image: train/negatives/2393.tiff
# Open background image: train/negatives/841false.tiff
# Open background image: train/negatives/2880.tiff
# Open background image: train/negatives/747false.tiff
# Open background image: train/negatives/4455.tiff
# Open background image: train/negatives/275.tiff
# Open background image: train/negatives/991false.tiff
# Open background image: train/negatives/393.tiff
# Open background image: train/negatives/189false.tiff
# Open background image: train/negatives/5200.tiff
# Open background image: train/negatives/529.tiff
# Open background image: train/negatives/148.tiff
# Open background image: train/negatives/1666.tiff
# Open background image: train/negatives/4899.tiff
# Open background image: train/negatives/1527.tiff
# Open background image: train/negatives/3357.tiff
# Open background image: train/negatives/52.tiff
# Open background image: train/negatives/746false.tiff
# Open background image: train/negatives/94.tiff
# Open background image: train/negatives/3710.tiff
# Open background image: train/negatives/283false.tiff
# Open background image: train/negatives/4482.tiff
# Open background image: train/negatives/193.tiff
# Open background image: train/negatives/4466.tiff
# Open background image: train/negatives/2338.tiff
# Open background image: train/negatives/379.tiff
# Open background image: train/negatives/2231.tiff
# Open background image: train/negatives/1166.tiff
# Open background image: train/negatives/4857.tiff
# Open background image: train/negatives/4675.tiff
# Open background image: train/negatives/2340.tiff
# Open background image: train/negatives/600false.tiff
# Open background image: train/negatives/447.tiff
# Open background image: train/negatives/2159.tiff
# Open background image: train/negatives/841false.tiff
# Open background image: train/negatives/403.tiff
# Open background image: train/negatives/136.tiff
# Open background image: train/negatives/288.tiff
# Open background image: train/negatives/4170.tiff
# Open background image: train/negatives/1938.tiff
# Open background image: train/negatives/284.tiff
# Open background image: train/negatives/5098.tiff
# Open background image: train/negatives/777false.tiff
# Open background image: train/negatives/4423.tiff
# Open background image: train/negatives/843false.tiff
# Open background image: train/negatives/227.tiff
# Open background image: train/negatives/983false.tiff
# Open background image: train/negatives/1038.tiff
# Open background image: train/negatives/3910.tiff
# Open background image: train/negatives/3411.tiff
# Open background image: train/negatives/3914.tiff
# Open background image: train/negatives/440false.tiff
# Open background image: train/negatives/899.tiff
# Open background image: train/negatives/542false.tiff
# Open background image: train/negatives/2416.tiff
# Open background image: train/negatives/604.tiff
# Open background image: train/negatives/1967.tiff
# Open background image: train/negatives/1019.tiff
# Open background image: train/negatives/2317.tiff
# Open background image: train/negatives/1750.tiff
# Open background image: train/negatives/1870.tiff
# Open background image: train/negatives/384false.tiff
# Open background image: train/negatives/5097.tiff
# Open background image: train/negatives/1668.tiff
# Open background image: train/negatives/365.tiff
# Open background image: train/negatives/326.tiff
# Open background image: train/negatives/2687.tiff
# Open background image: train/negatives/1564.tiff
# Open background image: train/negatives/3833.tiff
# Open background image: train/negatives/5031.tiff
# Open background image: train/negatives/5186.tiff
# Open background image: train/negatives/2842.tiff
# Open background image: train/negatives/716.tiff
# Open background image: train/negatives/155false.tiff
# Open background image: train/negatives/83false.tiff
# Open background image: train/negatives/2377.tiff
# Open background image: train/negatives/219.tiff
# Open background image: train/negatives/604false.tiff
# Open background image: train/negatives/2183.tiff
# Open background image: train/negatives/1175.tiff
# Open background image: train/negatives/651false.tiff
# Open background image: train/negatives/187.tiff
# Open background image: train/negatives/432.tiff
# Open background image: train/negatives/1034.tiff
# Open background image: train/negatives/113.tiff
# Open background image: train/negatives/20false.tiff
# Open background image: train/negatives/4077.tiff
# Open background image: train/negatives/1685.tiff
# Open background image: train/negatives/446.tiff
# Open background image: train/negatives/4773.tiff
# Open background image: train/negatives/569.tiff
# Open background image: train/negatives/3400.tiff
# Open background image: train/negatives/1020.tiff
# Open background image: train/negatives/2841.tiff
# Open background image: train/negatives/4319.tiff
# Open background image: train/negatives/104.tiff
# Open background image: train/negatives/2652.tiff
# Open background image: train/negatives/143.tiff
# Open background image: train/negatives/754.tiff
# Open background image: train/negatives/994false.tiff
# Open background image: train/negatives/2133.tiff
# Open background image: train/negatives/2638.tiff
# Open background image: train/negatives/513.tiff
# Open background image: train/negatives/2106.tiff
# Open background image: train/negatives/3637.tiff
# Open background image: train/negatives/345false.tiff
# Open background image: train/negatives/5098.tiff
# Open background image: train/negatives/27.tiff
# Open background image: train/negatives/784.tiff
# Open background image: train/negatives/5181.tiff
# Open background image: train/negatives/3032.tiff
# Open background image: train/negatives/536.tiff
# Open background image: train/negatives/862.tiff
# Open background image: train/negatives/3875.tiff
# Open background image: train/negatives/2959.tiff
# Open background image: train/negatives/302.tiff
# Open background image: train/negatives/730.tiff
# Open background image: train/negatives/4.tiff
# Open background image: train/negatives/5181.tiff
# Open background image: train/negatives/3717.tiff
# Open background image: train/negatives/3845.tiff
# Open background image: train/negatives/4705.tiff
# Open background image: train/negatives/2285.tiff
# Open background image: train/negatives/2238.tiff
# Open background image: train/negatives/532.tiff
# Open background image: train/negatives/1696.tiff
# Open background image: train/negatives/3544.tiff
# Open background image: train/negatives/2278.tiff
# Open background image: train/negatives/2206.tiff
# Open background image: train/negatives/37.tiff
# Open background image: train/negatives/891.tiff
# Open background image: train/negatives/2908.tiff
# Open background image: train/negatives/5194.tiff
# Open background image: train/negatives/4382.tiff
# Open background image: train/negatives/14.tiff
# Open background image: train/negatives/932.tiff
# Open background image: train/negatives/297.tiff
# Open background image: train/negatives/4788.tiff
# Open background image: train/negatives/116.tiff
# Open background image: train/negatives/3798.tiff
# Open background image: train/negatives/1532.tiff
# Open background image: train/negatives/827.tiff
# Open background image: train/negatives/3448.tiff
# Open background image: train/negatives/1885.tiff
# Open background image: train/negatives/1800.tiff
# Open background image: train/negatives/3716.tiff
# Open background image: train/negatives/663.tiff
# Open background image: train/negatives/4552.tiff
# Open background image: train/negatives/4440.tiff
# Open background image: train/negatives/4461.tiff
# Open background image: train/negatives/1061.tiff
# Open background image: train/negatives/2896.tiff
# Open background image: train/negatives/2208.tiff
# Open background image: train/negatives/2455.tiff
# Open background image: train/negatives/167.tiff
# Open background image: train/negatives/122.tiff
# Open background image: train/negatives/647.tiff
# Open background image: train/negatives/571.tiff
# Open background image: train/negatives/1624.tiff
# Open background image: train/negatives/594false.tiff
# Open background image: train/negatives/4180.tiff
# Open background image: train/negatives/1192.tiff
# Open background image: train/negatives/265false.tiff
# Open background image: train/negatives/182false.tiff
# Open background image: train/negatives/4850.tiff
# Open background image: train/negatives/4540.tiff
# Open background image: train/negatives/5030.tiff
# Open background image: train/negatives/2471.tiff
# Open background image: train/negatives/57.tiff
# Open background image: train/negatives/2012.tiff
# Open background image: train/negatives/680false.tiff
# Open background image: train/negatives/1712.tiff
# Open background image: train/negatives/4770.tiff
# Open background image: train/negatives/743.tiff
# Open background image: train/negatives/3021.tiff
# Open background image: train/negatives/4356.tiff
# Open background image: train/negatives/846.tiff
# Open background image: train/negatives/2965.tiff
# Open background image: train/negatives/289.tiff
# Open background image: train/negatives/1978.tiff
# Open background image: train/negatives/1902.tiff
# Open background image: train/negatives/78false.tiff
# Open background image: train/negatives/832.tiff
# Open background image: train/negatives/232false.tiff
# Open background image: train/negatives/1552.tiff
# Open background image: train/negatives/621.tiff
# Open background image: train/negatives/1489.tiff
# Open background image: train/negatives/738.tiff
# Open background image: train/negatives/569false.tiff
# Open background image: train/negatives/88false.tiff
# Open background image: train/negatives/534false.tiff
# Open background image: train/negatives/376false.tiff
# Open background image: train/negatives/124false.tiff
# Open background image: train/negatives/1957.tiff
# Open background image: train/negatives/968false.tiff
# Open background image: train/negatives/66.tiff
# Open background image: train/negatives/3057.tiff
# Open background image: train/negatives/689.tiff
# Open background image: train/negatives/264false.tiff
# Open background image: train/negatives/2849.tiff
# Open background image: train/negatives/1709.tiff
# Open background image: train/negatives/4046.tiff
# Open background image: train/negatives/2582.tiff
# Open background image: train/negatives/2122.tiff
# Open background image: train/negatives/2774.tiff
# Open background image: train/negatives/1975.tiff
# Open background image: train/negatives/11.tiff
# Open background image: train/negatives/531false.tiff
# Open background image: train/negatives/802.tiff
# Open background image: train/negatives/1980.tiff
# Open background image: train/negatives/2790.tiff
# Open background image: train/negatives/1619.tiff
# Open background image: train/negatives/2063.tiff
# Open background image: train/negatives/701.tiff
# Open background image: train/negatives/4129.tiff
# Open background image: train/negatives/4863.tiff
# Open background image: train/negatives/4421.tiff
# Open background image: train/negatives/2287.tiff
# Open background image: train/negatives/2864.tiff
# Open background image: train/negatives/4787.tiff
# Open background image: train/negatives/3904.tiff
# Open background image: train/negatives/4811.tiff
# Open background image: train/negatives/88.tiff
# Open background image: train/negatives/877false.tiff
# Open background image: train/negatives/2153.tiff
# Open background image: train/negatives/4096.tiff
# Open background image: train/negatives/4216.tiff
# Open background image: train/negatives/2155.tiff
# Open background image: train/negatives/1498.tiff
# Open background image: train/negatives/1778.tiff
# Open background image: train/negatives/5147.tiff
# Open background image: train/negatives/1840.tiff
# Open background image: train/negatives/636.tiff
# Open background image: train/negatives/2498.tiff
# Open background image: train/negatives/1165.tiff
# Open background image: train/negatives/3885.tiff
# Open background image: train/negatives/3526.tiff
# Open background image: train/negatives/313.tiff
# Open background image: train/negatives/925.tiff
# Open background image: train/negatives/1664.tiff
# Open background image: train/negatives/2876.tiff
# Open background image: train/negatives/4001.tiff
# Open background image: train/negatives/2293.tiff
# Open background image: train/negatives/4957.tiff
# Open background image: train/negatives/843.tiff
# Open background image: train/negatives/3317.tiff
# Open background image: train/negatives/3838.tiff
# Open background image: train/negatives/5203.tiff
# Open background image: train/negatives/3024.tiff
# Open background image: train/negatives/1787.tiff
# Open background image: train/negatives/2618.tiff
# Open background image: train/negatives/3054.tiff
# Open background image: train/negatives/1796.tiff
# Open background image: train/negatives/616false.tiff
# Open background image: train/negatives/1146.tiff
# Open background image: train/negatives/2283.tiff
# Open background image: train/negatives/457false.tiff
# Open background image: train/negatives/1015.tiff
# Open background image: train/negatives/877false.tiff
# Open background image: train/negatives/567false.tiff
# Open background image: train/negatives/755false.tiff
# Open background image: train/negatives/181.tiff
# Open background image: train/negatives/789false.tiff
# Open background image: train/negatives/2107.tiff
# Open background image: train/negatives/524.tiff
# Open background image: train/negatives/355false.tiff
# Open background image: train/negatives/2232.tiff
# Open background image: train/negatives/1032.tiff
# Open background image: train/negatives/1507.tiff
# Open background image: train/negatives/2149.tiff
# Open background image: train/negatives/123false.tiff
# Open background image: train/negatives/2337.tiff
# Open background image: train/negatives/177.tiff
# Open background image: train/negatives/3961.tiff
# Open background image: train/negatives/3771.tiff
# Open background image: train/negatives/4517.tiff
# Open background image: train/negatives/1114.tiff
# Open background image: train/negatives/120.tiff
# Open background image: train/negatives/4398.tiff
# Open background image: train/negatives/1932.tiff
# Open background image: train/negatives/4365.tiff
# Open background image: train/negatives/4078.tiff
# Open background image: train/negatives/1947.tiff
# Open background image: train/negatives/4925.tiff
# Open background image: train/negatives/1520.tiff
# Open background image: train/negatives/270.tiff
# Open background image: train/negatives/4959.tiff
# Open background image: train/negatives/158.tiff
# Open background image: train/negatives/266.tiff
# Open background image: train/negatives/5041.tiff
# Open background image: train/negatives/1660.tiff
# Open background image: train/negatives/213false.tiff
# Open background image: train/negatives/282false.tiff
# Open background image: train/negatives/5177.tiff
# Open background image: train/negatives/4424.tiff
# Open background image: train/negatives/3816.tiff
# Open background image: train/negatives/5101.tiff
# Open background image: train/negatives/3685.tiff
# Open background image: train/negatives/499false.tiff
# Open background image: train/negatives/4568.tiff
# Open background image: train/negatives/315false.tiff
# Open background image: train/negatives/94.tiff
# Open background image: train/negatives/744.tiff
# ...
# Open background image: train/negatives/317false.tiff
# Open background image: train/negatives/517false.tiff
# Open background image: train/negatives/566.tiff
# Open background image: train/negatives/5089.tiff
# Open background image: train/negatives/1797.tiff
# Open background image: train/negatives/2896.tiff
# Open background image: train/negatives/2094.tiff
# Open background image: train/negatives/1553.tiff
# Open background image: train/negatives/956false.tiff
# Open background image: train/negatives/848false.tiff
# Open background image: train/negatives/958false.tiff
# Open background image: train/negatives/2185.tiff
# Open background image: train/negatives/3688.tiff
# Open background image: train/negatives/842.tiff
# Open background image: train/negatives/936.tiff
# Open background image: train/negatives/2659.tiff
# Open background image: train/negatives/178false.tiff
# Open background image: train/negatives/11.tiff
# Open background image: train/negatives/616false.tiff
# Open background image: train/negatives/730.tiff
# Open background image: train/negatives/4809.tiff
# Open background image: train/negatives/1898.tiff
# Open background image: train/negatives/3471.tiff
# Open background image: train/negatives/418.tiff
# Open background image: train/negatives/12false.tiff
# Open background image: train/negatives/814.tiff
# Open background image: train/negatives/760.tiff
# Open background image: train/negatives/4251.tiff
# Open background image: train/negatives/258.tiff
# Open background image: train/negatives/52.tiff
# Open background image: train/negatives/4455.tiff
# Open background image: train/negatives/893false.tiff
# Open background image: train/negatives/2726.tiff
# Open background image: train/negatives/874false.tiff
# Open background image: train/negatives/125false.tiff
# Open background image: train/negatives/3946.tiff
# Open background image: train/negatives/529.tiff
# Open background image: train/negatives/745false.tiff
# Open background image: train/negatives/4680.tiff
# Open background image: train/negatives/543false.tiff
# Open background image: train/negatives/2255.tiff
# Open background image: train/negatives/10.tiff
# Open background image: train/negatives/4362.tiff
# Open background image: train/negatives/2012.tiff
# Open background image: train/negatives/4087.tiff
# Open background image: train/negatives/564.tiff
# Open background image: train/negatives/220.tiff
# Open background image: train/negatives/508.tiff
# Open background image: train/negatives/916false.tiff
# Open background image: train/negatives/66false.tiff
# Open background image: train/negatives/2225.tiff
# Open background image: train/negatives/3496.tiff
# Open background image: train/negatives/4012.tiff
# Open background image: train/negatives/1508.tiff
# Open background image: train/negatives/4326.tiff
# Open background image: train/negatives/5183.tiff
# Open background image: train/negatives/4808.tiff
# Open background image: train/negatives/203.tiff
# Open background image: train/negatives/3631.tiff
# Open background image: train/negatives/1583.tiff
# Open background image: train/negatives/982.tiff
# Open background image: train/negatives/5188.tiff
# Open background image: train/negatives/1532.tiff
# Open background image: train/negatives/3644.tiff
# Open background image: train/negatives/258false.tiff
# Open background image: train/negatives/358false.tiff
# Open background image: train/negatives/118false.tiff
# Open background image: train/negatives/1953.tiff
# Open background image: train/negatives/2284.tiff
# Open background image: train/negatives/3720.tiff
# Open background image: train/negatives/2528.tiff
# Open background image: train/negatives/651.tiff
# Open background image: train/negatives/1711.tiff
# Open background image: train/negatives/4721.tiff
# Open background image: train/negatives/171.tiff
# Open background image: train/negatives/4508.tiff
# Open background image: train/negatives/683.tiff
# Open background image: train/negatives/422false.tiff
# Open background image: train/negatives/19false.tiff
# Open background image: train/negatives/4480.tiff
# Open background image: train/negatives/1070.tiff
# Open background image: train/negatives/2643.tiff
# Open background image: train/negatives/234false.tiff
# Open background image: train/negatives/1549.tiff
# Open background image: train/negatives/4671.tiff
# Open background image: train/negatives/13.tiff
# Open background image: train/negatives/3349.tiff
# Open background image: train/negatives/2492.tiff
# Open background image: train/negatives/5069.tiff
# Open background image: train/negatives/481false.tiff
# Open background image: train/negatives/1903.tiff
# Open background image: train/negatives/5021.tiff
# Open background image: train/negatives/1610.tiff
# Open background image: train/negatives/641false.tiff
# Open background image: train/negatives/636.tiff
# Open background image: train/negatives/1941.tiff
# Open background image: train/negatives/3540.tiff
# Open background image: train/negatives/100false.tiff
# Open background image: train/negatives/1972.tiff
# Open background image: train/negatives/3987.tiff
# Open background image: train/negatives/2572.tiff
# Open background image: train/negatives/961false.tiff
# Open background image: train/negatives/305.tiff
# Open background image: train/negatives/5136.tiff
# Open background image: train/negatives/732false.tiff
# Open background image: train/negatives/1824.tiff
# Open background image: train/negatives/357false.tiff
# Open background image: train/negatives/267false.tiff
# Open background image: train/negatives/331.tiff
# Open background image: train/negatives/1576.tiff
# Open background image: train/negatives/5162.tiff
# Open background image: train/negatives/1095.tiff
# Open background image: train/negatives/236.tiff
# Open background image: train/negatives/752.tiff
# Open background image: train/negatives/35false.tiff
# Open background image: train/negatives/1892.tiff
# Open background image: train/negatives/100.tiff
# Open background image: train/negatives/3478.tiff
# Open background image: train/negatives/708false.tiff
# Open background image: train/negatives/2631.tiff
# Open background image: train/negatives/772false.tiff
# Open background image: train/negatives/1682.tiff
# Open background image: train/negatives/701.tiff
# Open background image: train/negatives/62false.tiff
# Open background image: train/negatives/909false.tiff
# Open background image: train/negatives/2355.tiff
# Open background image: train/negatives/320false.tiff
# Open background image: train/negatives/1215.tiff
# Open background image: train/negatives/437false.tiff
# Open background image: train/negatives/720false.tiff
# Open background image: train/negatives/4022.tiff
# Open background image: train/negatives/371.tiff
# Open background image: train/negatives/3432.tiff
# Open background image: train/negatives/4775.tiff
# Open background image: train/negatives/675false.tiff
# Open background image: train/negatives/316false.tiff
# Open background image: train/negatives/340false.tiff
# Open background image: train/negatives/1497.tiff
# Open background image: train/negatives/2992.tiff
# Open background image: train/negatives/3740.tiff
# Open background image: train/negatives/4824.tiff
# Open background image: train/negatives/339.tiff
# Open background image: train/negatives/66false.tiff
# Open background image: train/negatives/2742.tiff
# Open background image: train/negatives/394false.tiff
# Open background image: train/negatives/54false.tiff
# Open background image: train/negatives/716.tiff
# Open background image: train/negatives/1599.tiff
# Open background image: train/negatives/4705.tiff
# Open background image: train/negatives/754false.tiff
# Open background image: train/negatives/2818.tiff
# Open background image: train/negatives/4698.tiff
# Open background image: train/negatives/464.tiff
# Open background image: train/negatives/833.tiff
# Open background image: train/negatives/38.tiff
# Open background image: train/negatives/1174.tiff
# Open background image: train/negatives/492.tiff
# Open background image: train/negatives/428false.tiff
# Open background image: train/negatives/573.tiff
# Open background image: train/negatives/1022.tiff
# Open background image: train/negatives/4166.tiff
# Open background image: train/negatives/5086.tiff
# Open background image: train/negatives/1003.tiff
# Open background image: train/negatives/2567.tiff
# Open background image: train/negatives/150false.tiff
# Open background image: train/negatives/4268.tiff
# Open background image: train/negatives/2559.tiff
# Open background image: train/negatives/1610.tiff
# Open background image: train/negatives/623.tiff
# Open background image: train/negatives/4616.tiff
# Open background image: train/negatives/852false.tiff
# Open background image: train/negatives/794false.tiff
# Open background image: train/negatives/1032.tiff
# Open background image: train/negatives/4092.tiff
# Open background image: train/negatives/4976.tiff
# Open background image: train/negatives/3749.tiff
# Open background image: train/negatives/1986.tiff
# Open background image: train/negatives/3048.tiff
# Open background image: train/negatives/132false.tiff
# Open background image: train/negatives/735false.tiff
# Open background image: train/negatives/2719.tiff
# Open background image: train/negatives/5150.tiff
# Open background image: train/negatives/664.tiff
# Open background image: train/negatives/537false.tiff
# Open background image: train/negatives/12.tiff
# Open background image: train/negatives/3604.tiff
# Open background image: train/negatives/4243.tiff
# Open background image: train/negatives/105.tiff
# Open background image: train/negatives/1945.tiff
# Open background image: train/negatives/14false.tiff
# Open background image: train/negatives/285false.tiff
# Open background image: train/negatives/1897.tiff
# Open background image: train/negatives/3741.tiff
# Open background image: train/negatives/897false.tiff
# Open background image: train/negatives/159.tiff
# Open background image: train/negatives/3904.tiff
# Open background image: train/negatives/1028.tiff
# Open background image: train/negatives/5014.tiff
# Open background image: train/negatives/299false.tiff
# Open background image: train/negatives/1069.tiff
# Open background image: train/negatives/2412.tiff
# Open background image: train/negatives/2028.tiff
# Open background image: train/negatives/131.tiff
# Open background image: train/negatives/2864.tiff
# Open background image: train/negatives/947false.tiff
# Open background image: train/negatives/4565.tiff
# Open background image: train/negatives/200false.tiff
# Open background image: train/negatives/455.tiff
# Open background image: train/negatives/1603.tiff
# Open background image: train/negatives/4879.tiff
# Open background image: train/negatives/841.tiff
# Open background image: train/negatives/4003.tiff
# Open background image: train/negatives/3374.tiff
# Open background image: train/negatives/306.tiff
# Open background image: train/negatives/3749.tiff
# Open background image: train/negatives/359.tiff
# Open background image: train/negatives/4926.tiff
# Open background image: train/negatives/1120.tiff
# Open background image: train/negatives/4504.tiff
# Open background image: train/negatives/3849.tiff
# Open background image: train/negatives/236false.tiff
# Open background image: train/negatives/5109.tiff
# Open background image: train/negatives/4982.tiff
# Open background image: train/negatives/4402.tiff
# Open background image: train/negatives/636false.tiff
# Open background image: train/negatives/2093.tiff
# Open background image: train/negatives/730.tiff
# Open background image: train/negatives/509false.tiff
# Open background image: train/negatives/3063.tiff
# Open background image: train/negatives/930.tiff
# Open background image: train/negatives/3391.tiff
# Open background image: train/negatives/589.tiff
# Open background image: train/negatives/3456.tiff
# Open background image: train/negatives/2402.tiff
# Open background image: train/negatives/687false.tiff
# Open background image: train/negatives/2651.tiff
# Open background image: train/negatives/750false.tiff
# Open background image: train/negatives/2669.tiff
# Open background image: train/negatives/1531.tiff
# Open background image: train/negatives/3311.tiff
# Open background image: train/negatives/4060.tiff
# Open background image: train/negatives/2482.tiff
# Open background image: train/negatives/2880.tiff
# Open background image: train/negatives/1609.tiff
# Open background image: train/negatives/4369.tiff
# Open background image: train/negatives/2259.tiff
# Open background image: train/negatives/5070.tiff
# Open background image: train/negatives/2137.tiff
# Open background image: train/negatives/5073.tiff
# Open background image: train/negatives/2942.tiff
# Open background image: train/negatives/3031.tiff
# Open background image: train/negatives/603false.tiff
# Open background image: train/negatives/1642.tiff
# Open background image: train/negatives/5051.tiff
# Open background image: train/negatives/2872.tiff
# Open background image: train/negatives/4394.tiff
# Open background image: train/negatives/1862.tiff
# Open background image: train/negatives/1126.tiff
# Open background image: train/negatives/383false.tiff
# Open background image: train/negatives/2279.tiff
# Open background image: train/negatives/2971.tiff
# Open background image: train/negatives/432.tiff
# Open background image: train/negatives/930.tiff
# Open background image: train/negatives/3396.tiff
# Open background image: train/negatives/145.tiff
# Open background image: train/negatives/195false.tiff
# Open background image: train/negatives/1663.tiff
# Open background image: train/negatives/293false.tiff
# Open background image: train/negatives/1081.tiff
# Open background image: train/negatives/2309.tiff
# Open background image: train/negatives/735false.tiff
# Open background image: train/negatives/4179.tiff
# Open background image: train/negatives/2822.tiff
# Open background image: train/negatives/4565.tiff
# Open background image: train/negatives/743false.tiff
# Open background image: train/negatives/2976.tiff
# Open background image: train/negatives/652false.tiff
# Open background image: train/negatives/132false.tiff
# Open background image: train/negatives/1722.tiff
# Open background image: train/negatives/4740.tiff
# Open background image: train/negatives/2708.tiff
# Open background image: train/negatives/941false.tiff
# Open background image: train/negatives/3587.tiff
# Open background image: train/negatives/896.tiff
# Open background image: train/negatives/3848.tiff
# Open background image: train/negatives/1734.tiff
# Open background image: train/negatives/927false.tiff
# Open background image: train/negatives/832false.tiff
# Open background image: train/negatives/4472.tiff
# Open background image: train/negatives/937.tiff
# Open background image: train/negatives/20.tiff
# Open background image: train/negatives/932false.tiff
# Open background image: train/negatives/927.tiff
# Open background image: train/negatives/729false.tiff
# Open background image: train/negatives/234false.tiff
# Open background image: train/negatives/511.tiff
# Open background image: train/negatives/2109.tiff
# Open background image: train/negatives/175.tiff
# Open background image: train/negatives/956false.tiff
# Open background image: train/negatives/4674.tiff
# Open background image: train/negatives/585false.tiff
# Open background image: train/negatives/961false.tiff
# Open background image: train/negatives/939.tiff
# Open background image: train/negatives/720.tiff
# Open background image: train/negatives/2799.tiff
# Open background image: train/negatives/365.tiff
# Open background image: train/negatives/1774.tiff
# Open background image: train/negatives/153false.tiff
# Open background image: train/negatives/24false.tiff
# Open background image: train/negatives/4653.tiff
# Open background image: train/negatives/1560.tiff
# Open background image: train/negatives/2824.tiff
# Open background image: train/negatives/1729.tiff
# Open background image: train/negatives/974.tiff
# Open background image: train/negatives/2237.tiff
# Open background image: train/negatives/840false.tiff
# Open background image: train/negatives/2154.tiff
# Open background image: train/negatives/135.tiff
# Open background image: train/negatives/4487.tiff
# Open background image: train/negatives/548false.tiff
# Open background image: train/negatives/2409.tiff
# Done

# %% [markdown]
# # Renombramos y colocamos en raiz

# %%
dirs = glob.glob('train/samples/*')
for d in dirs:    
    for e in glob.glob(f'{d}/*.jpg'):
        os.rename(e,f'{e.split("/")[3][:-4]}_{"0"*(2-len(e.split("/")[2]))}{e.split("/")[2]}.jpg')

# %%
#dirs = glob.glob('train/samples/*')
#img = [e for e in [glob.glob(f'{d}/*.jpg') for d in dirs]]
#[os.replace(e, f"train/positives/{e.split('/')[3]}") for im in img for e in im];

# %%
#routes = glob.glob('train/positives/*.jpg')
#f= open("pos.info","w+")
#[f.write(f"{route} 1 0 0 44 44\n") for route in routes]
#f.close()

# %% [markdown]
# ### Creamos pos.info global

# %%
fout = open("result.txt", "wt")
inf = glob.glob('pos*.txt')
for i in inf:
    fin = open(i,"rt")
    for line in fin:
        fout.write(f'{line.split(".")[0]}_{i.split(".")[0][-2:]}.{line.split(".")[1]}')
    fin.close()
fout.close()

# %%
# !opencv_createsamples -info pos00.txt -bg bg.txt -vec pos.vec -num 3700 -w 34 -h 34
# Out:
# Info file name: pos00.txt
# Img file name: (NULL)
# Vec file name: pos.vec
# BG  file name: bg.txt
# Num: 3700
# BG color: 0
# BG threshold: 80
# Invert: FALSE
# Max intensity deviation: 40
# Max x angle: 1.1
# Max y angle: 1.1
# Max z angle: 0.5
# Show samples: FALSE
# Width: 34
# Height: 34
# Max Scale: -1
# RNG Seed: 12345
# Create training samples from images collection...
# Done. Created 3700 samples

# %%
# !opencv_traincascade -data train/cascade -vec pos.vec -bg bg.txt -numPos 2700 -numNeg 1000 -numStages 20 -featureType LBP -minHitRate 0.975 -maxFalseAlarmRate 0.5 -weightTrimRate 0.95 -w 34 -h 34
# Out:
# PARAMETERS:
# cascadeDirName: train/cascade
# vecFileName: pos.vec
# bgFileName: bg.txt
# numPos: 2700
# numNeg: 1000
# numStages: 20
# precalcValBufSize[Mb] : 1024
# precalcIdxBufSize[Mb] : 1024
# acceptanceRatioBreakValue : -1
# stageType: BOOST
# featureType: LBP
# sampleWidth: 34
# sampleHeight: 34
# boostType: GAB
# minHitRate: 0.975
# maxFalseAlarmRate: 0.5
# weightTrimRate: 0.95
# maxDepth: 1
# maxWeakCount: 100
# Number of unique features given windowSize [34,34] : 34969
#
# ===== TRAINING 0-stage =====
# <BEGIN
# POS count : consumed   2700 : 2700
# NEG count : acceptanceRatio    1000 : 1
# Precalculation time: 10
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1| 0.979259|     0.14|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 0 minutes 12 seconds.
#
# ===== TRAINING 1-stage =====
# <BEGIN
# POS count : consumed   2700 : 2757
# NEG count : acceptanceRatio    1000 : 0.157332
# Precalculation time: 11
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2| 0.994815|    0.299|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 0 minutes 25 seconds.
#
# ===== TRAINING 2-stage =====
# <BEGIN
# POS count : consumed   2700 : 2772
# NEG count : acceptanceRatio    1000 : 0.0533817
# Precalculation time: 9
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2| 0.996667|    0.443|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 0 minutes 38 seconds.
#
# ===== TRAINING 3-stage =====
# <BEGIN
# POS count : consumed   2700 : 2782
# NEG count : acceptanceRatio    1000 : 0.0268759
# Precalculation time: 9
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2| 0.991852|     0.39|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 0 minutes 50 seconds.
#
# ===== TRAINING 4-stage =====
# <BEGIN
# POS count : consumed   2700 : 2804
# NEG count : acceptanceRatio    1000 : 0.0114762
# Precalculation time: 10
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2| 0.994074|    0.482|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 1 minutes 3 seconds.
#
# ===== TRAINING 5-stage =====
# <BEGIN
# POS count : consumed   2700 : 2821
# NEG count : acceptanceRatio    1000 : 0.00643563
# Precalculation time: 10
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2| 0.986296|    0.453|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 1 minutes 19 seconds.
#
# ===== TRAINING 6-stage =====
# <BEGIN
# POS count : consumed   2700 : 2865
# NEG count : acceptanceRatio    1000 : 0.00331308
# Precalculation time: 10
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2| 0.988148|    0.502|
# +----+---------+---------+
# |   3| 0.981852|    0.366|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 1 minutes 43 seconds.
#
# ===== TRAINING 7-stage =====
# <BEGIN
# POS count : consumed   2700 : 2918
# NEG count : acceptanceRatio    1000 : 0.00148546
# Precalculation time: 10
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2| 0.988148|    0.436|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 2 minutes 13 seconds.
#
# ===== TRAINING 8-stage =====
# <BEGIN
# POS count : consumed   2700 : 2952
# NEG count : acceptanceRatio    1000 : 0.000746072
# Precalculation time: 10
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2| 0.995926|    0.569|
# +----+---------+---------+
# |   3| 0.985926|    0.368|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 3 minutes 7 seconds.
#
# ===== TRAINING 9-stage =====
# <BEGIN
# POS count : consumed   2700 : 2998
# NEG count : acceptanceRatio    1000 : 0.000321819
# Precalculation time: 10
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2| 0.987778|    0.492|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 4 minutes 48 seconds.
#
# ===== TRAINING 10-stage =====
# <BEGIN
# POS count : consumed   2700 : 3038
# NEG count : acceptanceRatio    1000 : 0.000177811
# Precalculation time: 9
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2| 0.994444|    0.502|
# +----+---------+---------+
# |   3| 0.982222|     0.37|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 8 minutes 6 seconds.
#
# ===== TRAINING 11-stage =====
# <BEGIN
# POS count : consumed   2700 : 3094
# NEG count : acceptanceRatio    1000 : 8.90619e-05
# Precalculation time: 9
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2| 0.994815|    0.503|
# +----+---------+---------+
# |   3| 0.977407|    0.337|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 14 minutes 13 seconds.
#
# ===== TRAINING 12-stage =====
# <BEGIN
# POS count : consumed   2700 : 3171
# NEG count : acceptanceRatio    1000 : 4.18023e-05
# Precalculation time: 9
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2| 0.995926|     0.57|
# +----+---------+---------+
# |   3| 0.985556|    0.434|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 0 hours 31 minutes 49 seconds.
#
# ===== TRAINING 13-stage =====
# <BEGIN
# POS count : consumed   2700 : 3224
# NEG count : acceptanceRatio    1000 : 1.84708e-05
# Precalculation time: 10
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2| 0.992593|    0.547|
# +----+---------+---------+
# |   3| 0.984074|    0.428|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 1 hours 6 minutes 21 seconds.
#
# ===== TRAINING 14-stage =====
# <BEGIN
# POS count : consumed   2700 : 3279
# NEG count : acceptanceRatio    1000 : 7.60844e-06
# Precalculation time: 10
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2| 0.987407|    0.488|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 2 hours 27 minutes 46 seconds.
#
# ===== TRAINING 15-stage =====
# <BEGIN
# POS count : consumed   2700 : 3322
# NEG count : acceptanceRatio    1000 : 3.7796e-06
# Precalculation time: 6
# +----+---------+---------+
# |  N |    HR   |    FA   |
# +----+---------+---------+
# |   1|        1|        1|
# +----+---------+---------+
# |   2| 0.985185|    0.407|
# +----+---------+---------+
# END>
# Training until now has taken 0 days 5 hours 18 minutes 38 seconds.
#
# ===== TRAINING 16-stage =====
# <BEGIN
# POS count : consumed   2700 : 3389
# NEG count : acceptanceRatio    0 : 0
# Required leaf false alarm rate achieved. Branch training terminated.
